# %% [markdown]
# Expectation propagation demo
# ===
#
# ForneyLab comes with support for expectation propagation (EP). In this demo we illustrate EP on the following model that links a continuous variable $u \in \mathbb{R}$ with a binary variable $z_i \in \{-1, 1\}$ through the constraint
# \begin{align*}
#     \sigma(z_i \cdot u)
# \end{align*}
# The factor graph below shows our generative model.
#
# ```
# ---> = ---> (u)
#      |
#      σ
#      |
#    (z_i)
# ```

# %%
using(ForneyLab)

n = 10

g = FactorGraph()

# Prior
u ~ GaussianMeanVariance(constant(0.0), constant(100.0))

# Observarion model
for i = 1:n
    z_i = Variable(id=:z_*i)
    Sigmoid(z_i, u)
    placeholder(z_i, :z, index=i)
end

# Assign id for easy lookup
u.id = :u
;

# %% [markdown]
# With the model defined, we can now generate an expectation propagation schedule.

# %%
schedule = expectationPropagationSchedule(u)

# Inspect schedule and graph
ForneyLab.draw(g, schedule=schedule)
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.36.0 (20140111.2315)
#  -->
# <!-- Title: G Pages: 1 -->
# <svg width="653pt" height="1142pt"
#  viewBox="0.00 0.00 653.00 1142.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 1138)">
# <title>G</title>
# <polygon fill="white" stroke="none" points="-4,4 -4,-1138 649,-1138 649,4 -4,4"/>
# <!-- 10551460262084793132 -->
# <g id="node1" class="node"><title>10551460262084793132</title>
# <polygon fill="none" stroke="black" points="456,-486 376,-486 376,-414 456,-414 456,-486"/>
# <text text-anchor="middle" x="416" y="-452.8" font-family="Times,serif" font-size="9.00">=</text>
# <text text-anchor="middle" x="416" y="-442.8" font-family="Times,serif" font-size="9.00">equ_variable_1_3</text>
# </g>
# <!-- 9657527793271362976 -->
# <g id="node13" class="node"><title>9657527793271362976</title>
# <polygon fill="none" stroke="black" points="73,-378 1,-378 1,-306 73,-306 73,-378"/>
# <text text-anchor="middle" x="37" y="-344.8" font-family="Times,serif" font-size="9.00">σ</text>
# <text text-anchor="middle" x="37" y="-334.8" font-family="Times,serif" font-size="9.00">sigmoid_3</text>
# </g>
# <!-- 10551460262084793132&#45;&#45;9657527793271362976 -->
# <g id="edge24" class="edge"><title>10551460262084793132&#45;&#45;9657527793271362976</title>
# <path fill="none" stroke="black" d="M375.917,-433.11C358.342,-426.554 337.348,-419.274 318,-414 235.921,-391.627 211.887,-401.067 130,-378 110.904,-372.621 90.1975,-365.012 73.1808,-358.261"/>
# <text text-anchor="middle" x="82.6808" y="-369.861" font-family="Times,serif" font-size="8.00">1 real</text>
# <text text-anchor="middle" x="82.6808" y="-360.861" font-family="Times,serif" font-size="8.00">((6))</text>
# <text text-anchor="middle" x="368.917" y="-444.71" font-family="Times,serif" font-size="8.00">1 1</text>
# <text text-anchor="middle" x="368.917" y="-435.71" font-family="Times,serif" font-size="8.00">(33)</text>
# </g>
# <!-- 16578659127023137273 -->
# <g id="node19" class="node"><title>16578659127023137273</title>
# <polygon fill="none" stroke="black" points="457,-378 377,-378 377,-306 457,-306 457,-378"/>
# <text text-anchor="middle" x="417" y="-344.8" font-family="Times,serif" font-size="9.00">=</text>
# <text text-anchor="middle" x="417" y="-334.8" font-family="Times,serif" font-size="9.00">equ_variable_1_2</text>
# </g>
# <!-- 10551460262084793132&#45;&#45;16578659127023137273 -->
# <g id="edge27" class="edge"><title>10551460262084793132&#45;&#45;16578659127023137273</title>
# <path fill="none" stroke="black" d="M416.33,-413.998C416.438,-402.54 416.558,-389.809 416.667,-378.328"/>
# <text text-anchor="middle" x="423.667" y="-389.928" font-family="Times,serif" font-size="8.00">3 3</text>
# <text text-anchor="middle" x="423.667" y="-380.928" font-family="Times,serif" font-size="8.00">(22)</text>
# <text text-anchor="middle" x="409.33" y="-407.598" font-family="Times,serif" font-size="8.00">2 2</text>
# <text text-anchor="middle" x="409.33" y="-398.598" font-family="Times,serif" font-size="8.00">(18)</text>
# </g>
# <!-- 10303527783788219927 -->
# <g id="node2" class="node"><title>10303527783788219927</title>
# <polygon fill="none" stroke="black" points="170,-162 98,-162 98,-90 170,-90 170,-162"/>
# <text text-anchor="middle" x="134" y="-128.8" font-family="Times,serif" font-size="9.00">σ</text>
# <text text-anchor="middle" x="134" y="-118.8" font-family="Times,serif" font-size="9.00">sigmoid_1</text>
# </g>
# <!-- 4847713312037144366 -->
# <g id="node3" class="node"><title>4847713312037144366</title>
# <polygon fill="none" stroke="black" points="456,-810 376,-810 376,-738 456,-738 456,-810"/>
# <text text-anchor="middle" x="416" y="-776.8" font-family="Times,serif" font-size="9.00">=</text>
# <text text-anchor="middle" x="416" y="-766.8" font-family="Times,serif" font-size="9.00">equ_variable_1_6</text>
# </g>
# <!-- 18297000694557902579 -->
# <g id="node9" class="node"><title>18297000694557902579</title>
# <polygon fill="none" stroke="black" points="261,-702 189,-702 189,-630 261,-630 261,-702"/>
# <text text-anchor="middle" x="225" y="-668.8" font-family="Times,serif" font-size="9.00">σ</text>
# <text text-anchor="middle" x="225" y="-658.8" font-family="Times,serif" font-size="9.00">sigmoid_6</text>
# </g>
# <!-- 4847713312037144366&#45;&#45;18297000694557902579 -->
# <g id="edge21" class="edge"><title>4847713312037144366&#45;&#45;18297000694557902579</title>
# <path fill="none" stroke="black" d="M375.96,-750.779C342.049,-731.959 293.862,-705.216 261.117,-687.044"/>
# <text text-anchor="middle" x="270.617" y="-698.644" font-family="Times,serif" font-size="8.00">1 real</text>
# <text text-anchor="middle" x="270.617" y="-689.644" font-family="Times,serif" font-size="8.00">((5))</text>
# <text text-anchor="middle" x="368.96" y="-762.379" font-family="Times,serif" font-size="8.00">1 1</text>
# <text text-anchor="middle" x="368.96" y="-753.379" font-family="Times,serif" font-size="8.00">(32)</text>
# </g>
# <!-- 3903048930017926410 -->
# <g id="node11" class="node"><title>3903048930017926410</title>
# <polygon fill="none" stroke="black" points="456,-702 376,-702 376,-630 456,-630 456,-702"/>
# <text text-anchor="middle" x="416" y="-668.8" font-family="Times,serif" font-size="9.00">=</text>
# <text text-anchor="middle" x="416" y="-658.8" font-family="Times,serif" font-size="9.00">equ_variable_1_5</text>
# </g>
# <!-- 4847713312037144366&#45;&#45;3903048930017926410 -->
# <g id="edge26" class="edge"><title>4847713312037144366&#45;&#45;3903048930017926410</title>
# <path fill="none" stroke="black" d="M416,-737.998C416,-726.54 416,-713.809 416,-702.328"/>
# <text text-anchor="middle" x="423" y="-713.928" font-family="Times,serif" font-size="8.00">3 3</text>
# <text text-anchor="middle" x="423" y="-704.928" font-family="Times,serif" font-size="8.00">(26)</text>
# <text text-anchor="middle" x="409" y="-731.598" font-family="Times,serif" font-size="8.00">2 2</text>
# <text text-anchor="middle" x="409" y="-722.598" font-family="Times,serif" font-size="8.00">(15)</text>
# </g>
# <!-- 15836128322798260123 -->
# <g id="node4" class="node"><title>15836128322798260123</title>
# <polygon fill="none" stroke="black" points="261,-594 189,-594 189,-522 261,-522 261,-594"/>
# <text text-anchor="middle" x="225" y="-560.8" font-family="Times,serif" font-size="9.00">σ</text>
# <text text-anchor="middle" x="225" y="-550.8" font-family="Times,serif" font-size="9.00">sigmoid_5</text>
# </g>
# <!-- 2358721282571369350 -->
# <g id="node5" class="node"><title>2358721282571369350</title>
# <polygon fill="none" stroke="black" points="261,-810 189,-810 189,-738 261,-738 261,-810"/>
# <text text-anchor="middle" x="225" y="-776.8" font-family="Times,serif" font-size="9.00">σ</text>
# <text text-anchor="middle" x="225" y="-766.8" font-family="Times,serif" font-size="9.00">sigmoid_7</text>
# </g>
# <!-- 10890572701530081115 -->
# <g id="node6" class="node"><title>10890572701530081115</title>
# <polygon fill="lightgrey" stroke="black" points="75,-261 1,-261 1,-207 75,-207 75,-261"/>
# <text text-anchor="middle" x="38" y="-231.8" font-family="Times,serif" font-size="9.00">placeholder_z_1</text>
# </g>
# <!-- 10890572701530081115&#45;&#45;10303527783788219927 -->
# <g id="edge23" class="edge"><title>10890572701530081115&#45;&#45;10303527783788219927</title>
# <path fill="none" stroke="black" d="M61.7303,-206.798C73.9456,-193.31 89.0067,-176.68 102.213,-162.099"/>
# <text text-anchor="middle" x="94.2125" y="-164.699" font-family="Times,serif" font-size="8.00">2 bin</text>
# <text text-anchor="middle" x="53.7303" y="-200.398" font-family="Times,serif" font-size="8.00">1 out</text>
# </g>
# <!-- 2842863826196681522 -->
# <g id="node7" class="node"><title>2842863826196681522</title>
# <polygon fill="none" stroke="black" points="456,-1026 376,-1026 376,-954 456,-954 456,-1026"/>
# <text text-anchor="middle" x="416" y="-992.8" font-family="Times,serif" font-size="9.00"

# %%
algo = messagePassingAlgorithm(schedule, u)

# Inspect the algorithm code
println(algo)
# Out:
# function init()
#
# messages = Array{Message}(38)
# messages[33] = vague(Message{Gaussian})
# messages[32] = vague(Message{Gaussian})
# messages[31] = vague(Message{Gaussian})
# messages[34] = vague(Message{Gaussian})
# messages[35] = vague(Message{Gaussian})
# messages[20] = vague(Message{Gaussian})
# messages[25] = vague(Message{Gaussian})
# messages[28] = vague(Message{Gaussian})
# messages[37] = vague(Message{Gaussian})
# messages[36] = vague(Message{Gaussian})
#
# return messages
#
# end
#
# function step!(data::Dict, marginals::Dict=Dict(), messages::Vector{Message}=Array{Message}(38))
#
# messages[1] = ruleEPSigmoidGP1(messages[20], Message(PointMass, m=data[:z][1]))
# messages[2] = ruleEPSigmoidGP1(messages[25], Message(PointMass, m=data[:z][5]))
# messages[3] = ruleEPSigmoidGP1(messages[28], Message(PointMass, m=data[:z][7]))
# messages[4] = ruleEPSigmoidGP1(messages[31], Message(PointMass, m=data[:z][10]))
# messages[5] = ruleEPSigmoidGP1(messages[32], Message(PointMass, m=data[:z][6]))
# messages[6] = ruleEPSigmoidGP1(messages[33], Message(PointMass, m=data[:z][3]))
# messages[7] = ruleEPSigmoidGP1(messages[34], Message(PointMass, m=data[:z][4]))
# messages[8] = ruleEPSigmoidGP1(messages[35], Message(PointMass, m=data[:z][2]))
# messages[9] = ruleEPSigmoidGP1(messages[36], Message(PointMass, m=data[:z][8]))
# messages[10] = ruleEPSigmoidGP1(messages[37], Message(PointMass, m=data[:z][9]))
# messages[11] = ruleSPGaussianMeanVariancePPV(Message(PointMass, m=0.0), Message(PointMass, m=100.0), nothing)
# messages[12] = ruleSPEqualityGaussian(messages[10], nothing, messages[4])
# messages[13] = ruleSPEqualityGaussian(messages[9], nothing, messages[12])
# messages[14] = ruleSPEqualityGaussian(messages[3], nothing, messages[13])
# messages[15] = ruleSPEqualityGaussian(messages[5], nothing, messages[14])
# messages[16] = ruleSPEqualityGaussian(messages[2], nothing, messages[15])
# messages[17] = ruleSPEqualityGaussian(messages[7], nothing, messages[16])
# messages[18] = ruleSPEqualityGaussian(messages[6], nothing, messages[17])
# messages[19] = ruleSPEqualityGaussian(messages[8], nothing, messages[18])
# messages[20] = ruleSPEqualityGaussian(messages[11], nothing, messages[19])
# messages[21] = ruleSPEqualityGaussian(messages[11], messages[1], nothing)
# messages[22] = ruleSPEqualityGaussian(messages[8], messages[21], nothing)
# messages[23] = ruleSPEqualityGaussian(messages[6], messages[22], nothing)
# messages[24] = ruleSPEqualityGaussian(messages[7], messages[23], nothing)
# messages[25] = ruleSPEqualityGaussian(nothing, messages[24], messages[15])
# messages[26] = ruleSPEqualityGaussian(messages[2], messages[24], nothing)
# messages[27] = ruleSPEqualityGaussian(messages[5], messages[26], nothing)
# messages[28] = ruleSPEqualityGaussian(nothing, messages[27], messages[13])
# messages[29] = ruleSPEqualityGaussian(messages[3], messages[27], nothing)
# messages[30] = ruleSPEqualityGaussian(messages[9], messages[29], nothing)
# messages[31] = ruleSPEqualityGaussian(messages[10], messages[30], nothing)
# messages[32] = ruleSPEqualityGaussian(nothing, messages[26], messages[14])
# messages[33] = ruleSPEqualityGaussian(nothing, messages[22], messages[17])
# messages[34] = ruleSPEqualityGaussian(nothing, messages[23], messages[16])
# messages[35] = ruleSPEqualityGaussian(nothing, messages[21], messages[18])
# messages[36] = ruleSPEqualityGaussian(nothing, messages[29], messages[12])
# messages[37] = ruleSPEqualityGaussian(nothing, messages[30], messages[4])
# messages[38] = ruleSPEqualityGaussian(nothing, messages[1], messages[19])
#
# marginals[:u] = messages[11].dist * messages[38].dist
#
# return marginals
#
# end

# %% [markdown]
# Note that the EP schedule requires message initializations. We can initialize the messages and iteratively execute the schedule.

# %%
# Toy dataset
u_true = 0.4
z = (2*rand(n) - 1 .< erf(u_true))
println(z)
# Out:
# Bool[true,false,true,true,true,true,true,false,true,false]

# %%
eval(parse("begin\n"*algo*"\nend")) # parse for multiple statements must be wrapped in block

messages = init()
marginals = Dict()
data = Dict(:z => z)

n_its = 2*n
for i = 1:n_its
   step!(data, marginals, messages)
end
;

# %%
# Inspect the results
println("True u: $(u_true)")
println("Number of samples: $(n)")
println("Sample mean of u: $(round(erfinv(2*mean(z) - 1),2))") # Convert mean of z to mean of u
println("\n----- Estimation after $(n_its) EP updates -----")
println("Estimated mean of u: $(round(mean(marginals[:u]),2)), with variance $(round(var(marginals[:u]),2))")
# Out:
# True u: 0.4
# Number of samples: 10
# Sample mean of u: 0.37
#
# ----- Estimation after 20 EP updates -----
# Estimated mean of u: 0.55, with variance 0.18
