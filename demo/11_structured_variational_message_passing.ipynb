# %% [markdown]
# Structured variational message passing demo
# ===
#
# A generalization of VMP under the mean field approximation is structured VMP (SVMP). SVMP allows arbitrary factorizations of the approximating `q` distributions (Dauwels 2007). As an example case to illustrate and test our SVMP implementation in ForneyLab, again we estimate the mean and variance of samples drawn from a Gaussian distribution. However this time we factorize the approximating distribution as `q(m,gam,y)=q(m,gam)q(y)`.
#
# Where the previous demo illustrated a batch algorithm, this demo will estimate the parameters in an online context. The subgraph definitions are as follows:
#
# ```
#          gam_0        gam_1
# [T]---------------[=]------>[T]
#     m_0      m_1   |
# [T]---->[=]--------|------->[T]      .         .
#          |         |                 .q(m, gam).
#        m --->[N]<--- gam             . .>[N]<. .
#               .                           |
#               . q(y)                      | y
#               v                           v
#                                          [T]
# ```
#
# We begin by implementing the graph in ForneyLab and defining the structured factoriation. Note that the edges for `m` and `gam` now belong to the same subgraph.

# %%
using(ForneyLab)

# Initialize nodes and edges
g_node = GaussianNode(; name="g_node", form="precision")
m_eq_node = EqualityNode(; name="m_eq_node") # Equality node for mean
gam_eq_node = EqualityNode(; name="gam_eq_node") # Equality node for precision
y_node = TerminalNode(name="y_node") # Observed y values are stored in y_node
m_n_min_1_node = PriorNode(GaussianDistribution(m=0.0, V=100.0), name="m_n_min_1") # Prior
gam_n_min_1_node = PriorNode(GammaDistribution(a=0.01, b=0.01), name="gam_n_min_1") # Prior
m_n_node = TerminalNode(vague(GaussianDistribution), name="m_n")
gam_n_node = TerminalNode(vague(GammaDistribution), name="gam_n")

Edge(g_node.out, y_node.out, GaussianDistribution)
Edge(m_eq_node.interfaces[3], g_node.mean, GaussianDistribution)
Edge(gam_eq_node.interfaces[3], g_node.precision, GammaDistribution)
Edge(m_n_min_1_node.out, m_eq_node.interfaces[1], GaussianDistribution)
Edge(gam_n_min_1_node.out, gam_eq_node.interfaces[1], GammaDistribution)
Edge(m_eq_node.interfaces[2], m_n_node.out, GaussianDistribution)
Edge(gam_eq_node.interfaces[2], gam_n_node.out, GammaDistribution);

# %% [markdown]
# Now we need to specify the factorization, update schedules for both subgraphs and set the vague (almost uninformative) marginals.

# %%
# Generate some data
true_mean = 5.0
true_prec = 0.5
n_samples = 100 # Draw 100 samples
n_its = 10 # Iterations per data sample
y_vals = randn(n_samples)*(1/sqrt(true_prec))+true_mean
data = [DeltaDistribution(y) for y in y_vals]

# Set wraps
wrap(m_n_node, m_n_min_1_node)
wrap(gam_n_node, gam_n_min_1_node)

# Add read and write buffers
y_buffer = setReadBuffer(y_node, data)
m_est = setWriteBuffer(m_eq_node.interfaces[2])
gam_est = setWriteBuffer(gam_eq_node.interfaces[2])

# Define the structured variational algorithm
algo = VMP.Algorithm(Set{Edge}({g_node.out.edge}), n_iterations=n_its)

# Inspect the factorization (optional)
for subgraph in algo.fields[:factorization].factors
    draw(subgraph)
end

# %% [markdown]
# Now the setup is done and we can start the iterations.

# %%
run(algo)

# %% [markdown]
# Let's inspect the results.

# %%
println("True mean: $(true_mean)")
println("True precision: $(true_prec)")
println("Number of samples: $(n_samples)")
println("Sample mean: $(mean(y_vals))")
println("Sample precision: $(1/var(y_vals))")
println("\n----- Online estimation after $(n_its) VMP updates per sample -----")
println("Mean estimate: $(mean(m_est[end])[1]), with variance $(var(m_est[end])[1,1])")
println("Precision estimate: $(mean(gam_est[end])), with variance $(var(gam_est[end]))")
# Out:
# True mean: 5.0
# True precision: 0.5
# Number of samples: 100
# Sample mean: 5.053876393255727
# Sample precision: 0.5001103306513727
#
# ----- Online estimation after 10 VMP updates per sample -----
# Mean estimate: 5.059250380282573, with variance 0.026053610641148348
# Precision estimate: 0.4365865096434779, with variance 0.0038113933293876154
