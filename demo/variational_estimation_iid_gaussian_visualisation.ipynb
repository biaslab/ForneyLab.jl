# %% [markdown]
# # Variational Message Passing for Estimation
#
# ForneyLab comes with support for variational message passing (VMP) (Dauwels, 2007):
#
# - Dauwels J., On variational message passing on factor graphs, IEEE Intl symposium on information theory, Nice (France), June 2007
#
# In this demo we illustrate VMP by estimating the mean and precision (inverse variance) of a Gaussian distribution from samples. The model is defined as:
#
# \begin{align*}
#     m   &\sim \mathcal{N}(0, 100)\\
#     w   &\sim \mathcal{G}am(0.01, 0.01)\\
#     y_i &\sim \mathcal{N}(m, w^{-1}) \,\,\text{for}\,\, i=1,\ldots,n
# \end{align*}
#
# Variational inference approximates the exact posterior over $m$ and $w$ by a factorized posterior distribution. We minimize the KL divergence between the factorized posterior distribution and the exact posterior through variational message passing.
#
# Let's first generate a data set

# %%
# Generate toy data set
n = 5

m_data = 3.0
w_data = 4.0
y_data = sqrt(1/w_data)*randn(n) .+ m_data;

# %% [markdown]
# # Model specification

# %%
using(ForneyLab)

g = FactorGraph()

# Priors
@RV m ~ GaussianMeanVariance(0.0, 100.0)
@RV w ~ Gamma(0.01, 0.01)

# Observarion model
y = Vector{Variable}(undef, n)
for i = 1:n
    @RV y[i] ~ GaussianMeanPrecision(m, w)
    placeholder(y[i], :y, index=i)
end

# %% [markdown]
# # Debug dump for visualisation frontend
#
# It is possible to use model specification and inference results to inspect algorithm performance in FactorGraphViewer visualsation frontend. Visuaslisation frontend will show actual graph structure, passed messages, score heatmap etc. in a nice UI.
#
# To create a static dump we can use `makeDump` function which accepts an instance of `FactorGraph` object. Later we shall use this static dump during our inference steps and free energy computation.

# %%
algorithm_dump = makeDump(g);

# %% [markdown]
# # Algorithm generation
#
# With the model defined, we can now specify a **factorized posterior distribution**
#
# $$\begin{align*}
#     q(m, w) = q(m)\times q(w)
# \end{align*}$$
#
# through the `PosteriorFactorization()` constructor. All variables that are deterministically linked to the argument variables (e.g. through a `+` or `=` relation) automatically become part of a single posterior factor. We can also inspect the subgraph corresponding to a posterior factor with the `ForneyLab.draw()` function.

# %%
# Specify posterior factorization
q = PosteriorFactorization(m, w, ids=[:M, :W])

# Inspect the subgraph for m
ForneyLab.draw(q.posterior_factors[:M])
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.44.1 (20200629.0846)
#  -->
# <!-- Title: G Pages: 1 -->
# <svg width="1096pt" height="596pt"
#  viewBox="0.00 0.00 1096.40 596.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 592)">
# <title>G</title>
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-592 1092.4,-592 1092.4,4 -4,4"/>
# <!-- 7978885483401741212 -->
# <g id="node1" class="node">
# <title>7978885483401741212</title>
# <polygon fill="none" stroke="black" points="692.9,-354 620.9,-354 620.9,-282 692.9,-282 692.9,-354"/>
# <text text-anchor="middle" x="656.9" y="-320.8" font-family="Times,serif" font-size="9.00">=</text>
# <text text-anchor="middle" x="656.9" y="-310.8" font-family="Times,serif" font-size="9.00">equ_m_2</text>
# </g>
# <!-- 8084901489819187122 -->
# <g id="node5" class="node">
# <title>8084901489819187122</title>
# <polygon fill="none" stroke="black" points="190.4,-237 83.4,-237 83.4,-165 190.4,-165 190.4,-237"/>
# <text text-anchor="middle" x="136.9" y="-203.8" font-family="Times,serif" font-size="9.00">𝒩</text>
# <text text-anchor="middle" x="136.9" y="-193.8" font-family="Times,serif" font-size="9.00">gaussianmeanprecision_2</text>
# </g>
# <!-- 7978885483401741212&#45;&#45;8084901489819187122 -->
# <g id="edge3" class="edge">
# <title>7978885483401741212&#45;&#45;8084901489819187122</title>
# <path fill="none" stroke="black" d="M620.82,-309.92C553.05,-296.51 402.19,-266.14 275.9,-237 247.66,-230.48 216.33,-222.65 190.58,-216.04"/>
# <text text-anchor="start" x="390.9" y="-257.6" font-family="Times,serif" font-size="8.00" fill="red">m</text>
# <text text-anchor="start" x="190.58" y="-218.64" font-family="Times,serif" font-size="8.00">2 m </text>
# <text text-anchor="start" x="607.82" y="-312.52" font-family="Times,serif" font-size="8.00">1 1 </text>
# </g>
# <!-- 942294051312613177 -->
# <g id="node7" class="node">
# <title>942294051312613177</title>
# <polygon fill="none" stroke="black" points="692.9,-237 620.9,-237 620.9,-165 692.9,-165 692.9,-237"/>
# <text text-anchor="middle" x="656.9" y="-203.8" font-family="Times,serif" font-size="9.00">=</text>
# <text text-anchor="middle" x="656.9" y="-193.8" font-family="Times,serif" font-size="9.00">equ_m_1</text>
# </g>
# <!-- 7978885483401741212&#45;&#45;942294051312613177 -->
# <g id="edge8" class="edge">
# <title>7978885483401741212&#45;&#45;942294051312613177</title>
# <path fill="none" stroke="black" d="M656.9,-281.87C656.9,-267.74 656.9,-251.46 656.9,-237.31"/>
# <text text-anchor="start" x="656.9" y="-257.6" font-family="Times,serif" font-size="8.00" fill="red">m</text>
# <text text-anchor="start" x="643.9" y="-239.91" font-family="Times,serif" font-size="8.00">3 3 </text>
# <text text-anchor="start" x="643.9" y="-275.47" font-family="Times,serif" font-size="8.00">2 2 </text>
# </g>
# <!-- 14392341604533674024 -->
# <g id="node2" class="node">
# <title>14392341604533674024</title>
# <polygon fill="none" stroke="black" points="518.4,-120 411.4,-120 411.4,-48 518.4,-48 518.4,-120"/>
# <text text-anchor="middle" x="464.9" y="-86.8" font-family="Times,serif" font-size="9.00">𝒩</text>
# <text text-anchor="middle" x="464.9" y="-76.8" font-family="Times,serif" font-size="9.00">gaussianmeanprecision_1</text>
# </g>
# <!-- 5756866628314860012 -->
# <g id="node3" class="node">
# <title>5756866628314860012</title>
# <polygon fill="none" stroke="black" points="718.9,-471 646.9,-471 646.9,-399 718.9,-399 718.9,-471"/>
# <text text-anchor="middle" x="682.9" y="-437.8" font-family="Times,serif" font-size="9.00">=</text>
# <text text-anchor="middle" x="682.9" y="-427.8" font-family="Times,serif" font-size="9.00">equ_m_3</text>
# </g>
# <!-- 5756866628314860012&#45;&#45;7978885483401741212 -->
# <g id="edge7" class="edge">
# <title>5756866628314860012&#45;&#45;7978885483401741212</title>
# <path fill="none" stroke="black" d="M674.96,-398.87C671.77,-384.74 668.09,-368.46 664.89,-354.31"/>
# <text text-anchor="start" x="670.9" y="-374.6" font-family="Times,serif" font-size="8.00" fill="red">m</text>
# <text text-anchor="start" x="651.89" y="-356.91" font-family="Times,serif" font-size="8.00">3 3 </text>
# <text text-anchor="start" x="661.96" y="-392.47" font-family="Times,serif" font-size="8.00">2 2 </text>
# </g>
# <!-- 12176719349325885133 -->
# <g id="node6" class="node">
# <title>12176719349325885133</title>
# <polygon fill="none" stroke="black" points="364.4,-354 257.4,-354 257.4,-282 364.4,-282 364.4,-354"/>
# <text text-anchor="middle" x="310.9" y="-320.8" font-family="Times,serif" font-size="9.00">𝒩</text>
# <text text-anchor="middle" x="310.9" y="-310.8" font-family="Times,serif" font-size="9.00">gaussianmeanprecision_3</text>
# </g>
# <!-- 5756866628314860012&#45;&#45;12176719349325885133 -->
# <g id="edge2" class="edge">
# <title>5756866628314860012&#45;&#45;12176719349325885133</title>
# <path fill="none" stroke="black" d="M646.53,-419.72C629.19,-413.1 608.09,-405.32 588.9,-399 511.63,-373.54 420.83,-348.26 364.57,-333.14"/>
# <text text-anchor="start" x="528.9" y="-374.6" font-family="Times,serif" font-size="8.00" fill="red">m</text>
# <text text-anchor="start" x="364.57" y="-335.74" font-family="Times,serif" font-size="8.00">2 m </text>
# <text text-anchor="start" x="633.53" y="-422.32" font-family="Times,serif" font-size="8.00">1 1 </text>
# </g>
# <!-- 154783652302360351 -->
# <g id="node4" class="node">
# <title>154783652302360351</title>
# <polygon fill="none" stroke="black" points="1015.4,-471 908.4,-471 908.4,-399 1015.4,-399 1015.4,-471"/>
# <text text-anchor="middle" x="961.9" y="-437.8" font-family="Times,serif" font-size="9.00">𝒩</text>
# <text text-anchor="middle" x="961.9" y="-427.8" font-family="Times,serif" font-size="9.00">gaussianmeanprecision_4</text>
# </g>
# <!-- 942294051312613177&#45;&#45;14392341604533674024 -->
# <g id="edge4" class="edge">
# <title>942294051312613177&#45;&#45;14392341604533674024</title>
# <path fill="none" stroke="black" d="M620.79,-178.37C592,-161.13 551.26,-136.72 518.64,-117.19"/>
# <text text-anchor="start" x="566.9" y="-140.6" font-family="Times,serif" font-size="8.00" fill="red">m</text>
# <text text-anchor="start" x="518.64" y="-119.79" font-family="Times,serif" font-size="8.00">2 m </text>
# <text text-anchor="start" x="607.79" y="-180.97" font-family="Times,serif" font-size="8.00">2 2 </text>
# </g>
# <!-- 1151956397718470575 -->
# <g id="node8" class="node">
# <title>1151956397718470575</title>
# <polygon fill="none" stroke="black" points="821.9,-120 717.9,-120 717.9,-48 821.9,-48 821.9,-120"/>
# <text text-anchor="middle" x="769.9" y="-86.8" font-family="Times,serif" font-size="9.00">𝒩</text>
# <text text-anchor="middle" x="769.9" y="-76.8" font-family="Times,serif" font-size="9.00">gaussianmeanvariance_1</text>
# </g>
# <!-- 942294051312613177&#45;&#45;1151956397718470575 -->
# <g id="edge6" class="edge">
# <title>942294051312613177&#45;&#45;1151956397718470575</title>
# <path fill="none" stroke="black" d="M691.42,-164.87C705.31,-150.74 721.3,-134.46 735.21,-120.31"/>
# <text text-anchor="start" x="716.9" y="-140.6" font-family="Times,serif" font-size="8.00" fill="red">m</text>
# <text text-anchor="start" x="716.21" y="-122.91" font-family="Times,serif" font-size="8.00">1 out </text>
# <text text-anchor="start" x="678.42" y="-158.47" font-family="Times,serif" font-size="8.00">1 1 </text>
# </g>
# <!-- 15696495718017713171 -->
# <g id="node11" class="node">
# <title>15696495718017713171</title>
# </g>
# <!-- 1151956397718470575&#45;&#45;15696495718017713171 -->
# <g id="edge19" class="edge">
# <title>1151956397718470575&#45;&#45;15696495718017713171</title>
# <path fill="none" stroke="black" stroke-dasharray="5,2" d="M740.99,-47.88C729.08,-33.43 716.68,-18.37 710.65,-11.05"/>
# <text text-anchor="middle" x="702.65" y="-13.65" font-family="Times,serif" font-size="8.00">1 out</text>
# <text text-anchor="middle" x="734.49" y="-41.48" font-family="Times,serif" font-size="8.00">2 m</text>
# </g>
# <!-- 1608

# %%
# Inspect the subgraph for W
ForneyLab.draw(q.posterior_factors[:W])
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.44.1 (20200629.0846)
#  -->
# <!-- Title: G Pages: 1 -->
# <svg width="1183pt" height="596pt"
#  viewBox="0.00 0.00 1182.75 596.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 592)">
# <title>G</title>
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-592 1178.75,-592 1178.75,4 -4,4"/>
# <!-- 17195435265351351158 -->
# <g id="node1" class="node">
# <title>17195435265351351158</title>
# <polygon fill="none" stroke="black" points="158.25,-354 86.25,-354 86.25,-282 158.25,-282 158.25,-354"/>
# <text text-anchor="middle" x="122.25" y="-320.8" font-family="Times,serif" font-size="9.00">=</text>
# <text text-anchor="middle" x="122.25" y="-310.8" font-family="Times,serif" font-size="9.00">equ_w_2</text>
# </g>
# <!-- 8084901489819187122 -->
# <g id="node3" class="node">
# <title>8084901489819187122</title>
# <polygon fill="none" stroke="black" points="333.75,-237 226.75,-237 226.75,-165 333.75,-165 333.75,-237"/>
# <text text-anchor="middle" x="280.25" y="-203.8" font-family="Times,serif" font-size="9.00">𝒩</text>
# <text text-anchor="middle" x="280.25" y="-193.8" font-family="Times,serif" font-size="9.00">gaussianmeanprecision_2</text>
# </g>
# <!-- 17195435265351351158&#45;&#45;8084901489819187122 -->
# <g id="edge7" class="edge">
# <title>17195435265351351158&#45;&#45;8084901489819187122</title>
# <path fill="none" stroke="black" d="M158.5,-290.62C180.28,-274.77 208.25,-254.41 231.89,-237.2"/>
# <text text-anchor="start" x="206.25" y="-257.6" font-family="Times,serif" font-size="8.00" fill="red">w</text>
# <text text-anchor="start" x="216.89" y="-239.8" font-family="Times,serif" font-size="8.00">3 w </text>
# <text text-anchor="start" x="158.5" y="-293.22" font-family="Times,serif" font-size="8.00">1 1 </text>
# </g>
# <!-- 3011834740468711642 -->
# <g id="node7" class="node">
# <title>3011834740468711642</title>
# <polygon fill="none" stroke="black" points="111.25,-237 39.25,-237 39.25,-165 111.25,-165 111.25,-237"/>
# <text text-anchor="middle" x="75.25" y="-203.8" font-family="Times,serif" font-size="9.00">=</text>
# <text text-anchor="middle" x="75.25" y="-193.8" font-family="Times,serif" font-size="9.00">equ_w_1</text>
# </g>
# <!-- 17195435265351351158&#45;&#45;3011834740468711642 -->
# <g id="edge8" class="edge">
# <title>17195435265351351158&#45;&#45;3011834740468711642</title>
# <path fill="none" stroke="black" d="M91.73,-281.78C88.02,-276.12 84.69,-270.1 82.25,-264 78.92,-255.65 77.02,-246.2 75.96,-237.23"/>
# <text text-anchor="start" x="82.25" y="-257.6" font-family="Times,serif" font-size="8.00" fill="red">w</text>
# <text text-anchor="start" x="62.96" y="-239.83" font-family="Times,serif" font-size="8.00">3 3 </text>
# <text text-anchor="start" x="78.73" y="-275.38" font-family="Times,serif" font-size="8.00">2 2 </text>
# </g>
# <!-- 6998236467348028853 -->
# <g id="node2" class="node">
# <title>6998236467348028853</title>
# <polygon fill="none" stroke="black" points="645.25,-588 573.25,-588 573.25,-516 645.25,-516 645.25,-588"/>
# <text text-anchor="middle" x="609.25" y="-554.8" font-family="Times,serif" font-size="9.00">=</text>
# <text text-anchor="middle" x="609.25" y="-544.8" font-family="Times,serif" font-size="9.00">equ_w_4</text>
# </g>
# <!-- 154783652302360351 -->
# <g id="node4" class="node">
# <title>154783652302360351</title>
# <polygon fill="none" stroke="black" points="869.75,-471 762.75,-471 762.75,-399 869.75,-399 869.75,-471"/>
# <text text-anchor="middle" x="816.25" y="-437.8" font-family="Times,serif" font-size="9.00">𝒩</text>
# <text text-anchor="middle" x="816.25" y="-427.8" font-family="Times,serif" font-size="9.00">gaussianmeanprecision_4</text>
# </g>
# <!-- 6998236467348028853&#45;&#45;154783652302360351 -->
# <g id="edge9" class="edge">
# <title>6998236467348028853&#45;&#45;154783652302360351</title>
# <path fill="none" stroke="black" d="M603.39,-515.85C603.65,-506.17 605.9,-496.33 612.25,-489 639.82,-457.18 664.44,-481.35 705.25,-471 724.15,-466.21 744.58,-460.06 762.69,-454.25"/>
# <text text-anchor="start" x="612.25" y="-491.6" font-family="Times,serif" font-size="8.00" fill="red">w</text>
# <text text-anchor="start" x="747.69" y="-456.85" font-family="Times,serif" font-size="8.00">3 w </text>
# <text text-anchor="start" x="590.39" y="-509.45" font-family="Times,serif" font-size="8.00">1 1 </text>
# </g>
# <!-- 17368763584104746066 -->
# <g id="node6" class="node">
# <title>17368763584104746066</title>
# <polygon fill="none" stroke="black" points="395.25,-471 323.25,-471 323.25,-399 395.25,-399 395.25,-471"/>
# <text text-anchor="middle" x="359.25" y="-437.8" font-family="Times,serif" font-size="9.00">=</text>
# <text text-anchor="middle" x="359.25" y="-427.8" font-family="Times,serif" font-size="9.00">equ_w_3</text>
# </g>
# <!-- 6998236467348028853&#45;&#45;17368763584104746066 -->
# <g id="edge4" class="edge">
# <title>6998236467348028853&#45;&#45;17368763584104746066</title>
# <path fill="none" stroke="black" d="M573.17,-534.4C525.71,-512.57 442.78,-474.42 395.33,-452.59"/>
# <text text-anchor="start" x="492.25" y="-491.6" font-family="Times,serif" font-size="8.00" fill="red">w</text>
# <text text-anchor="start" x="395.33" y="-455.19" font-family="Times,serif" font-size="8.00">3 3 </text>
# <text text-anchor="start" x="560.17" y="-537" font-family="Times,serif" font-size="8.00">2 2 </text>
# </g>
# <!-- 15630560754196741771 -->
# <g id="node8" class="node">
# <title>15630560754196741771</title>
# <polygon fill="none" stroke="black" points="1101.75,-471 994.75,-471 994.75,-399 1101.75,-399 1101.75,-471"/>
# <text text-anchor="middle" x="1048.25" y="-437.8" font-family="Times,serif" font-size="9.00">𝒩</text>
# <text text-anchor="middle" x="1048.25" y="-427.8" font-family="Times,serif" font-size="9.00">gaussianmeanprecision_5</text>
# </g>
# <!-- 6998236467348028853&#45;&#45;15630560754196741771 -->
# <g id="edge5" class="edge">
# <title>6998236467348028853&#45;&#45;15630560754196741771</title>
# <path fill="none" stroke="black" d="M645.33,-541.41C672.28,-534.29 710.04,-524.4 743.25,-516 824.87,-495.36 845.91,-492.7 927.25,-471 949.33,-465.11 973.55,-458.2 994.48,-452.08"/>
# <text text-anchor="start" x="854.25" y="-491.6" font-family="Times,serif" font-size="8.00" fill="red">w</text>
# <text text-anchor="start" x="979.48" y="-454.68" font-family="Times,serif" font-size="8.00">3 w </text>
# <text text-anchor="start" x="645.33" y="-544.01" font-family="Times,serif" font-size="8.00">3 3 </text>
# </g>
# <!-- 12176719349325885133 -->
# <g id="node5" class="node">
# <title>12176719349325885133</title>
# <polygon fill="none" stroke="black" points="632.75,-354 525.75,-354 525.75,-282 632.75,-282 632.75,-354"/>
# <text text-anchor="middle" x="579.25" y="-320.8" font-family="Times,serif" font-size="9.00">𝒩</text>
# <text text-anchor="middle" x="579.25" y="-310.8" font-family="Times,serif" font-size="9.00">gaussianmeanprecision_3</text>
# </g>
# <!-- 17368763584104746066&#45;&#45;17195435265351351158 -->
# <g id="edge2" class="edge">
# <title>17368763584104746066&#45;&#45;17195435265351351158</title>
# <path fill="none" stroke="black" d="M323,-416.41C278.39,-394.76 203.11,-358.23 158.5,-336.59"/>
# <text text-anchor="start" x="248.25" y="-374.6" font-family="Times,serif" font-size="8.00" fill="red">w</text>
# <text text-anchor="start" x="158.5" y="-339.19" font-family="Times,serif" font-size="8.00">3 3 </text>
# <text text-anchor="start" x="310" y="-419.01" font-family="Times,serif" font-size="8.00">2 2 </text>
# </g>
# <!-- 17368763584104746066&#45;&#45;12176719349325885133 -->
# <g id="edge1" class="edge">
# <title>17368763584104746066&#45;&#45;12176719349325885133</title>
# <path fill="none" stroke="black" d="M395.58,-415.01C430.97,-396.51 485.2,-368.16 525.57,-347.06"/>
# <text text-anchor="start" x="476.25" y="-374.6" font-family="Times,serif" font-size="8.00" fill="red">w</text>
# <text text-anchor="start" x="510.57" y="-349.66" fon

# %%
# Build the variational update algorithms for each posterior factor
algo = messagePassingAlgorithm(free_energy = true)


# Generate source code for the algorithms
# algorithmSourceCode function accepts optional debug argument which can be used to setup a debug environment for the algorithm. 
# In this case it would be possible to use static dump object during inference steps and free energy computation.
source_code = algorithmSourceCode(algo, free_energy=true, debug = true)

# And inspect the algorithm code
println(source_code)
# Out:
# begin
#
# function stepM!(data::Dict, marginals::Dict=Dict(), messages::Vector{Message}=Array{Message}(undef, 10); dump::Union{GraphDump, Nothing} = nothing)
#
#
# push!(dump.steps[end].messages, Vector{MessageData}())
#
# push!(dump.steps[end].marginals, Vector{MarginalData}())
# messages[1] = ruleVBGaussianMeanVarianceOut(nothing, ProbabilityDistribution(Univariate, PointMass, m=0.0), ProbabilityDistribution(Univariate, PointMass, m=100.0))
#
# pushMessage!(dump, "gaussianmeanvariance_1_equ_m_1", "forward", messages[1])
# messages[2] = ruleVBGaussianMeanPrecisionM(ProbabilityDistribution(Univariate, PointMass, m=data[:y][4]), nothing, marginals[:w])
#
# pushMessage!(dump, "gaussianmeanprecision_4_equ_m_4", "forward", messages[2])
# messages[3] = ruleVBGaussianMeanPrecisionM(ProbabilityDistribution(Univariate, PointMass, m=data[:y][5]), nothing, marginals[:w])
#
# pushMessage!(dump, "gaussianmeanprecision_5_equ_m_4", "forward", messages[3])
# messages[4] = ruleSPEqualityGaussian(messages[2], nothing, messages[3])
#
# pushMessage!(dump, "equ_m_3_equ_m_4", "backward", messages[4])
# messages[5] = ruleVBGaussianMeanPrecisionM(ProbabilityDistribution(Univariate, PointMass, m=data[:y][3]), nothing, marginals[:w])
#
# pushMessage!(dump, "gaussianmeanprecision_3_equ_m_3", "forward", messages[5])
# messages[6] = ruleSPEqualityGaussian(messages[5], nothing, messages[4])
#
# pushMessage!(dump, "equ_m_2_equ_m_3", "backward", messages[6])
# messages[7] = ruleVBGaussianMeanPrecisionM(ProbabilityDistribution(Univariate, PointMass, m=data[:y][2]), nothing, marginals[:w])
#
# pushMessage!(dump, "gaussianmeanprecision_2_equ_m_2", "forward", messages[7])
# messages[8] = ruleSPEqualityGaussian(messages[7], nothing, messages[6])
#
# pushMessage!(dump, "equ_m_1_equ_m_2", "backward", messages[8])
# messages[9] = ruleVBGaussianMeanPrecisionM(ProbabilityDistribution(Univariate, PointMass, m=data[:y][1]), nothing, marginals[:w])
#
# pushMessage!(dump, "gaussianmeanprecision_1_equ_m_1", "forward", messages[9])
# messages[10] = ruleSPEqualityGaussian(nothing, messages[9], messages[8])
#
# pushMessage!(dump, "gaussianmeanvariance_1_equ_m_1", "backward", messages[10])
#
# marginals[:m] = messages[1].dist * messages[10].dist
# pushMarginal!(dump, "m", ["gaussianmeanvariance_1_equ_m_1", "gaussianmeanprecision_1_equ_m_1", "gaussianmeanprecision_2_equ_m_2", "equ_m_1_equ_m_2", "gaussianmeanprecision_3_equ_m_3", "equ_m_2_equ_m_3", "gaussianmeanprecision_4_equ_m_4", "equ_m_3_equ_m_4", "gaussianmeanprecision_5_equ_m_4"], marginals[:m])
#
#
# return marginals
#
# end
#
# function stepW!(data::Dict, marginals::Dict=Dict(), messages::Vector{Message}=Array{Message}(undef, 10); dump::Union{GraphDump, Nothing} = nothing)
#
#
# push!(dump.steps[end].messages, Vector{MessageData}())
#
# push!(dump.steps[end].marginals, Vector{MarginalData}())
# messages[1] = ruleVBGammaOut(nothing, ProbabilityDistribution(Univariate, PointMass, m=0.01), ProbabilityDistribution(Univariate, PointMass, m=0.01))
#
# pushMessage!(dump, "gamma_1_equ_w_1", "forward", messages[1])
# messages[2] = ruleVBGaussianMeanPrecisionW(ProbabilityDistribution(Univariate, PointMass, m=data[:y][4]), marginals[:m], nothing)
#
# pushMessage!(dump, "gaussianmeanprecision_4_equ_w_4", "forward", messages[2])
# messages[3] = ruleVBGaussianMeanPrecisionW(ProbabilityDistribution(Univariate, PointMass, m=data[:y][5]), marginals[:m], nothing)
#
# pushMessage!(dump, "gaussianmeanprecision_5_equ_w_4", "forward", messages[3])
# messages[4] = ruleSPEqualityGammaWishart(messages[2], nothing, messages[3])
#
# pushMessage!(dump, "equ_w_3_equ_w_4", "backward", messages[4])
# messages[5] = ruleVBGaussianMeanPrecisionW(ProbabilityDistribution(Univariate, PointMass, m=data[:y][3]), marginals[:m], nothing)
#
# pushMessage!(dump, "gaussianmeanprecision_3_equ_w_3", "forward", messages[5])
# messages[6] = ruleSPEqualityGammaWishart(messages[5], nothing, messages[4])
#
# pushMessage!(dump, "equ_w_2_equ_w_3", "backward", messages[6])
# messages[7] = ruleVBGaussianMeanPrecisionW(ProbabilityDistribution(Univariate, PointMass, m=data[:y][2]), marginals[:m], nothing)
#
# pushMessage!(dump, "gaussianmeanprecision_2_equ_w_2", "forward", messages[7])
# messages[8] = ruleSPEqualityGammaWishart(messages[7], nothing, messages[6])
#
# pushMessage!(dump, "equ_w_1_equ_w_2", "backward", messages[8])
# messages[9] = ruleVBGaussianMeanPrecisionW(ProbabilityDistribution(Univariate, PointMass, m=data[:y][1]), marginals[:m], nothing)
#
# pushMessage!(dump, "gaussianmeanprecision_1_equ_w_1", "forward", messages[9])
# messages[10] = ruleSPEqualityGammaWishart(nothing, messages[9], messages[8])
#
# pushMessage!(dump, "gamma_1_equ_w_1", "backward", messages[10])
#
# marginals[:w] = messages[1].dist * messages[10].dist
# pushMarginal!(dump, "w", ["gamma_1_equ_w_1", "gaussianmeanprecision_1_equ_w_1", "gaussianmeanprecision_2_equ_w_2", "equ_w_1_equ_w_2", "gaussianmeanprecision_3_equ_w_3", "equ_w_2_equ_w_3", "gaussianmeanprecision_4_equ_w_4", "equ_w_3_equ_w_4", "gaussianmeanprecision_5_equ_w_4"], marginals[:w])
#
#
# return marginals
#
# end
#
# function freeEnergy(data::Dict, marginals::Dict; dump::Union{GraphDump, Nothing}=nothing)
#
# F = 0.0
#
# v = averageEnergy(Gamma, marginals[:w], ProbabilityDistribution(Univariate, PointMass, m=0.01), ProbabilityDistribution(Univariate, PointMass, m=0.01))
# pushScore!(dump, "gamma_1", v,  "average_energy")
# F += v
# v = averageEnergy(GaussianMeanPrecision, ProbabilityDistribution(Univariate, PointMass, m=data[:y][1]), marginals[:m], marginals[:w])
# pushScore!(dump, "gaussianmeanprecision_1", v,  "average_energy")
# F += v
# v = averageEnergy(GaussianMeanPrecision, ProbabilityDistribution(Univariate, PointMass, m=data[:y][2]), marginals[:m], marginals[:w])
# pushScore!(dump, "gaussianmeanprecision_2", v,  "average_energy")
# F += v
# v = averageEnergy(GaussianMeanPrecision, ProbabilityDistribution(Univariate, PointMass, m=data[:y][3]), marginals[:m], marginals[:w])
# pushScore!(dump, "gaussianmeanprecision_3", v,  "average_energy")
# F += v
# v = averageEnergy(GaussianMeanPrecision, ProbabilityDistribution(Univariate, PointMass, m=data[:y][4]), marginals[:m], marginals[:w])
# pushScore!(dump, "gaussianmeanprecision_4", v,  "average_energy")
# F += v
# v = averageEnergy(GaussianMeanPrecision, ProbabilityDistribution(Univariate, PointMass, m=data[:y][5]), marginals[:m], marginals[:w])
# pushScore!(dump, "gaussianmeanprecision_5", v,  "average_energy")
# F += v
# v = averageEnergy(GaussianMeanVariance, marginals[:m], ProbabilityDistribution(Univariate, PointMass, m=0.0), ProbabilityDistribution(Univariate, PointMass, m=100.0))
# pushScore!(dump, "gaussianmeanvariance_1", v,  "average_energy")
# F += v
#
# v = differentialEntropy(marginals[:m])
# pushScore!(dump, "gaussianmeanvariance_1_equ_m_1", v, "entropy")
# pushScore!(dump, "gaussianmeanprecision_1_equ_m_1", v, "entropy")
# pushScore!(dump, "gaussianmeanprecision_2_equ_m_2", v, "entropy")
# pushScore!(dump, "equ_m_1_equ_m_2", v, "entropy")
# pushScore!(dump, "gaussianmeanprecision_3_equ_m_3", v, "entropy")
# pushScore!(dump, "equ_m_2_equ_m_3", v, "entropy")
# pushScore!(dump, "gaussianmeanprecision_4_equ_m_4", v, "entropy")
# pushScore!(dump, "equ_m_3_equ_m_4", v, "entropy")
# pushScore!(dump, "gaussianmeanprecision_5_equ_m_4", v, "entropy")
# F -= v
# v = differentialEntropy(marginals[:w])
# pushScore!(dump, "gamma_1_equ_w_1", v, "entropy")
# pushScore!(dump, "gaussianmeanprecision_1_equ_w_1", v, "entropy")
# pushScore!(dump, "gaussianmeanprecision_2_equ_w_2", v, "entropy")
# pushScore!(dump, "equ_w_1_equ_w_2", v, "entropy")
# pushScore!(dump, "gaussianmeanprecision_3_equ_w_3", v, "entropy")
# pushScore!(dump, "equ_w_2_equ_w_3", v, "entropy")
# pushScore!(dump, "gaussianmeanprecision_4_equ_w_4", v, "entropy")
# pushScore!(dump, "equ_w_3_equ_w_4", v, "entropy")
# pushScore!(dump, "gaussianmeanprecision_5_equ_w_4", v, "entropy")
# F -= v
#
# if dump !== nothing
#     push!(dump.steps, AlgorithmStep())
# end
# return F
#
# end
#
# end # block

# %% [markdown]
# Note that the algorithm now contains two `step!()` functions: one for each posterior factor. This is because variational message passing is an iterative algorithm, where `stepM!()` requires the marginal from `marginals[:w]` and `stepW!()` requires `marginals[:m]`. This requires us to initialize the marginals before we start the inference. The marginals argument allows us to pass an initial dictionary of marginals. Upon execution, this dictionary is updated in-place with the newly computed outcomes.
#
# Additionally, we can also automatically generate code that evaluates the free energy by passing `free_energy=true` to `algorithmSourceCode` function. This yields a model-specific `freeEnergy()` function that accepts the data and marginals dictionaries.
#
# The free energy can be used to check for convergence or to perform model comparisons.

# %% [markdown]
# # Execution

# %%
# Load algorithm
eval(Meta.parse(source_code));

# %% [markdown]
# As mentioned before, we need to initialize the `marginals` dictionary. After initialization, we iteratively step through the algorithm functions and evaluate the free energy and estimates after each iteration (for visualization purposes).

# %%
data = Dict(:y => y_data)

# Initial posterior factors
marginals = Dict(:m => vague(GaussianMeanVariance),
                 :w => vague(Gamma))

n_its = 2*n
F = Vector{Float64}(undef, n_its) # Initialize vector for storing Free energy
m_est = Vector{Float64}(undef, n_its)
w_est = Vector{Float64}(undef, n_its)
for i = 1:n_its
    stepM!(data, marginals, dump = algorithm_dump)
    stepW!(data, marginals, dump = algorithm_dump)
    
    # Store free energy
    F[i] = freeEnergy(data, marginals, dump = algorithm_dump)
end
;

# %% [markdown]
# # Results
# In order to evaluate the approximated solution that we obtained using VMP, we will first solve this same problem using exact inference so that later we can compare them both.

# %%
using PyPlot, PyCall, SpecialFunctions 
mlines = pyimport("matplotlib.lines")

# Definition of the normal-gamma distribution
Z(μ₀, κ₀, α₀, β₀) = gamma(α₀)/(β₀^α₀)*(2*π/κ₀)^(0.5) # normalization constant
NG(rμ, rλ, D, μ₀, κ₀, α₀, β₀) = [ (1/Z(μ₀, κ₀, α₀, β₀))*λ^(α₀-0.5)*exp(-(λ/2)*((κ₀*(μ-μ₀)^2)+(2*β₀))) for μ=rμ, λ=rλ ] 

# Calculates posterior distribution using exact inference
function exactPosterior(rμ, rλ, D, μ₀, κ₀, α₀, β₀)
    n = length(D)
    x̄ = sum(D) / n
    μₙ = (κ₀*μ₀ + n*x̄)/(κ₀ + n)
    κₙ = κ₀ + n
    αₙ = α₀ + n/2
    βₙ = β₀ + 0.5*var(D,corrected=false)*n + (κ₀*n*(x̄ - μ₀)^2)/(2*(κ₀+n))
    NG(rμ, rλ, D, μₙ, κₙ, αₙ, βₙ)
end
;

# %% [markdown]
# We can now compare both solutions by overlaying them on the same contour plot.

# %%
# Define the x and y limits for the contour plot
std_dev_ml = sqrt(var(y_data)/length(y_data))
rμ = range(mean(y_data)-3*std_dev_ml, mean(y_data)+3*std_dev_ml, length=1000)
rτ = range(0, 3(1/var(y_data)), length=1000)

# Plot the solution found using exact inference
contour([μ for μ=rμ, τ=rτ], [τ for μ=rμ, τ=rτ], exactPosterior(rμ, rτ, y_data, 0, 0.01, 0.01, 0.01), cmap="Greens")

# Generate a mesh grid of the approximated solution needed by the contour plot function
normal(x, μ, σ²) = (1/(sqrt(2π*σ²))) * exp.(-(x .- μ).^2 / (2*σ²)) # definition of the Gaussian distribution
Gam(λ, a, b) = (1/factorial(a-1)) * b^a * λ.^(a-1) .* exp.(-b*λ) # definition of the gamma distribution
approx(rμ, rτ, m_μ, v_μ, a_ω, b_ω) = [normal(μ, m_μ, v_μ) * Gam(τ, a_ω, b_ω) for μ=rμ, τ=rτ ]

# Plot the approximated solution found using VMP
contour([μ for μ=rμ, τ=rτ], [τ for μ=rμ, τ=rτ], 
    approx(rμ, rτ, mean(marginals[:m]), var(marginals[:m]), marginals[:w].params[:a], marginals[:w].params[:b]), cmap="Reds")

# Add a legend, a grid and labels to the plot
green_patch = mlines.Line2D([], [], color="green", label="Exact solution")
red_patch = mlines.Line2D([], [], color="red", label="Approximated solution")
legend(handles=[green_patch, red_patch], loc="upper left"); grid(true); xlabel("Mean"); ylabel("Precision");
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %% [markdown]
# The plot below shows the convergence of the free energy.

# %%
# Plot free energy to check for convergence
plot(1:n_its, F, color="black", marker="o")
grid(true); xlabel("Iteration"); ylabel("F"); xlim([1, length(F)]);
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %% [markdown]
# # Debug dump
#
# We can use `save` function to dump inference results and free energy computation into a `.JSON` file which can be used later in a visualisation frontend to inspect algorithm performance

# %%
save(algorithm_dump, output = "variational_estimation_iid_gaussian_visualisation.json")
